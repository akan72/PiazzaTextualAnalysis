# %%
import os
import pandas as pd
from piazza_api import Piazza

# %%
# https://github.com/hfaran/piazza-api
p = Piazza()
p.user_login(email=os.environ['PIAZZA_EMAIL'], password=os.environ['PIAZZA_PASSWORD'])

# %%
user_profile = p.get_user_profile()

# %%
print(user_profile)
# Out:
# {'side_projects': [], 'status_when': 2019, 'courses_stud': {}, 'roles': ['Engineering - Software', 'Data Science', 'Sciences', 'Research Scientist', 'Non Technical', 'Consulting', 'Finance', 'Product & Design', 'Product Design', 'Product Management', 'Full Stack (web)', 'Backend (web)', 'Distributed Systems', 'Databases'], 'research': [], 'skills': [{'level': 2, 'name': 'Python'}, {'level': 2, 'name': 'Java'}, {'level': 2, 'name': 'SQL'}], 'companies': [], 'status_what': 'fulltime', 'school_id': 'gokwpvey6YT', 'school': 'University of North Carolina at Chapel Hill', 'contact': {'skype': None, 'website': None, 'phone': None, 'email': 'lexokan@live.unc.edu'}, 'last_update': 1566952238291, 'links': {'twitter': None, 'github': 'https://github.com/akan72', 'facebook': None, 'linkedin': 'https://www.linkedin.com/in/alexanderkan/', 'stackoverflow': None}, 'company': {'co_hj5xfgmkoMW': {'streams': ['ev_jlqnpbwkfv2142_rsvp', 'ev_jlqndh2ds782o2_rsvp'], 'reached': '2019-03-01T18:44:57Z', 'campaign': {'cc_jsqephrk1ye6wk': {'cu_id': 'cu_j66tsskql982p7', 'cu_ms': 1551465897, 'term': 'term_0', 'read': 1}}, 'has_viewed': 1}, 'co_hj5xfgstozN': {'claimed': 1, 'reached': '2019-01-31T15:24:42Z', 'campaign': {'cc_jmuqwhe865t67k': {'cu_id': 'cu_j6p3di1elpp39l', 'cu_ms': 1538667507, 'term': 'term_0', 'read': 1}, 'cc_jrkrt5dkatb1dz': {'cu_id': 'cu_jlwca3x7euq1lb', 'cu_ms': 1548948282, 'term': 'term_0', 'read': 1}}, 'streams': ['jrkrpxpj4whsa_folder']}, 'co_hsnwdzmnyds5c9': {'streams': ['ev_jmt4rqizxx34kg_rsvp']}, 'co_jgpdtp0wu9749x': {'streams': ['jn3dj072il327a_folder'], 'claimed': 1, 'reached': '2018-10-10T16:45:44Z', 'campaign': {'cc_jn3dy4t5j8x49w': {'cu_id': 'cu_jiywb38xcmt2by', 'cu_ms': 1539189944, 'term': 'term_0', 'read': 1}}}, 'co_ibcq4lnj9ut6qu': {'claimed': 1, 'reached': '2019-01-07T17:19:03Z', 'campaign': {'cc_jplitukmbtu1id': {'cu_id': 'cu_jeafbf30w3o23t', 'cu_ms': 1544640097, 'term': 'term_0', 'read': 1}, 'cc_jqmk8mfestw1pn': {'cu_id': 'cu_jeafbf30w3o23t', 'cu_ms': 1546879716, 'term': 'term_0', 'read': 1}, 'cc_jqmlbu7gj8879c': {'cu_id': 'cu_jeafbf30w3o23t', 'cu_ms': 1546881543, 'term': 'term_0', 'read': 1}}, 'streams': ['jqml878ea6j65p_folder', 'jqml90lr52r69w_folder']}, 'co_hj5xfgutHiG': {'has_viewed': 1, 'has_viewed_long': 1549979093533}, 'co_if4jxbdps4y3ls': {'claimed': 1, 'reached': '2019-03-29T16:29:16Z', 'term_0': {'viewed': {'cu_jp8m230ok9d2m3': 1553872245}}, 'streams': ['term_0cu_jp8m230ok9d2m3_view', 'jtu71sy3b9z6sk_folder', 'jrwi213gily7e0_folder'], 'campaign': {'cc_jtua7sale1a4bp': {'cu_id': 'cu_jp8m230ok9d2m3', 'cu_ms': 1553876956, 'term': 'term_0', 'read': 1}}}, 'co_ijxgepwk8976s0': {'streams': ['jwjcsw2ldng4x1_folder', 'term_0cu_jrqjll3r9sh3ja_view'], 'claimed': 1, 'reached': '2019-06-05T22:28:27Z', 'exported': {'cu_jpvhxt1awzx6ee': 1559773706}, 'exported_last': 1559773706, 'term_0': {'viewed': {'cu_jrqjll3r9sh3ja': 1559770268}}}, 'co_jj07edgcwfa1qn': {'streams': ['jx0g3m4ohca2e9_folder']}, 'co_ipy5bkon5ph6uu': {'has_viewed': 1}}, 'photo_url': 'https://d1b10bmlvqabco.cloudfront.net/photos/j1b3q2admci2j3/1536442865_35.png', 'resume_req': {}, 'email': 'lexokan@live.unc.edu', 'views': {'co_if4jxbdps4y3ls': 1, 'co_ijxgepwk8976s0': 3}, 'work_experience': [{'role': 'Data Engineering Intern', 'city': 'Seattle', 'year': 2019, 'company': 'Facebook', 'type': 'intern', 'quarter': 'Summer'}, {'role': 'Software Engineering Intern', 'city': 'South San Francisco, California', 'year': 2018, 'company': 'Genentech', 'type': 'intern', 'quarter': 'Summer'}], 'splash_data': {'searches': [{'cuid': 'cu_jz90qyeee0m4ar', 'company_id': 'co_j4hg6lof11i4f6', 'internal_id': 'adobe', 'when_str': 'October 31, 2019', 'elements': 0, 'company': 'Adobe', 'type': 'basic', 'when': 1572495838000, 'sections': {'year': [], 'skill': [], 'program': [], 'keyword_resume': []}}, {'cuid': 'cu_jz90qyeee0m4ar', 'company_id': 'co_j4hg6lof11i4f6', 'internal_id': 'adobe', 'when_str': 'October 31, 2019', 'elements': 0, 'company': 'Adobe', 'type': 'basic', 'when': 1572495776 ...

# %%
user_profile.keys()
# Out:
# dict_keys(['side_projects', 'status_when', 'courses_stud', 'roles', 'research', 'skills', 'companies', 'status_what', 'school_id', 'school', 'contact', 'last_update', 'links', 'company', 'photo_url', 'resume_req', 'email', 'views', 'work_experience', 'splash_data', 'resume', 'courses_inst', 'work', 'profile_settings', 'preference', 'academics', 'photo', 'tags', 'worked_at', 'profile_progress', 'user_id', 'schools', 'awards', 'visa', 'name', 'last_resume_upload', 'network_signal', 'all_classes', 'status'])
